# %%
from dataframe_creation import *
import glob

# %%
lista_arquivos = []
for arquivo in glob.glob(r'/home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-EMERGENCIAL/*pdf'):
  if arquivo not in lista_arquivos:
    lista_arquivos.append(arquivo)

df_auxilio_emergencial = transforma_dataframe_novo(lista_arquivos, "auxilio_emergencial")

# %%
df_auxilio_emergencial
# Out:
#                                        nome_documento  \
# 0   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 1   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 2   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 3   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 4   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 5   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 6   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 7   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 8   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 9   /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 10  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 11  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 12  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 13  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 14  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 15  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 16  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 17  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 18  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
# 19  /home/juliano/TRF5/trf5.peticoes/20 - AUXÍLIO-...
#
#                                      conteudo_peticao        classificacao
# 0   EXCELENTÍSSIMO SENHOR JUIZ FEDERAL JUIZADO ESP...  auxilio_emergencial
# 1   JUÍZO VARA JUIZADO ESPECIAL FEDERAL SEÇÃO JUDI...  auxilio_emergencial
# 2   JUÍZO JUIZADO ESPECIAL FEDERAL COMARCA DOS PAL...  auxilio_emergencial
# 3   EXCELENTÍSSIMO SENHOR JUIZ FEDERAL VARA JUIZAD...  auxilio_emergencial
# 4   JUIZO FEDERAL SUBSEÇÃO JUDICIÁRIA PERNAMBUCO V...  auxilio_emergencial
# 5                                                      auxilio_emergencial
# 6   EXCELENTÍSSIMO SENHOR DOUTOR JUIZ ÍZA FEDERAL ...  auxilio_emergencial
# 7   EXCELENTÍSSIMO JUÍZO VARA FEDERAL DOS JUIZADOS...  auxilio_emergencial
# 8                                                      auxilio_emergencial
# 9   EXCELENTÍSSIMO SENHOR DOUTOR JUIZ JUIZADO ESPE...  auxilio_emergencial
# 10  EXCELENTÍSSIMO SENHOR DOUTOR JUIZ FEDERAL JUIZ...  auxilio_emergencial
# 11  JUÍZO JUIZADO ESPECIAL FEDERAL SUBSEÇÃO JUDICI...  auxilio_emergencial
# 12  Justiça Região PJe Processo Judicial Eletrônic...  auxilio_emergencial
# 13  JUIZADO ESPECIAL FEDERAL ADJUNTO VARA SUBSEÇÃO...  auxilio_emergencial
# 14  JUÍZO 13ª VARA FEDERAL SUBSEÇÃO JUDICIÁRIA MOS...  auxilio_emergencial
# 15  Justiça Região PJe Processo Judicial Eletrônic...  auxilio_emergencial
# 16  EXCELENTÍSSIMO SENHOR DOUTOR JUIZ DIREITO JUIZ...  auxilio_emergencial
# 17  JUÍZO TRIBUNAL REGIONAL FEDERAL REGIÃO TUTELA ...  auxilio_emergencial
# 18  Exmo Juiz Juizado Especial Subseção Judiciária...  auxilio_emergencial
# 19  EGRÉGIO TRIBUNAL JUSTIÇA FEDERAL VARA JUIZADO ...  auxilio_emergencial
